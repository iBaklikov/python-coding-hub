# %%
import os
from datetime import datetime
# All attributes and methods
# osdir = dir(os)
# for  lib in osdir:
#     print(lib)

# Print current directory
print(os.getcwd())

# Novigate to the new location
os.chdir(r'D:\Users\u124935\OneDrive - Finance of America Holdings, LLC\Desktop')
print(os.getcwd())

# Print content of the current directory
# list_dir = os.listdir()
# for element in list_dir:
#     print(element)

# Create new folder 
# one level
# os.mkdir('OS-demo-3')
# multiple levels deep
# os.makedirs('OS-demo-4/os-sub-demo-4')

# print (os.listdir('OS-demo-3'))
# print (os.listdir('OS-demo-4'))

# list_dir = os.listdir()
# for element in list_dir:
#     print(element)

# Delete folders
# # os.rmdir('OS-demo-2')
# os.removedirs('OS-demo-2/os-sub-demo-2')
# os.removedirs('OS-demo-4/os-sub-demo-4')

# Rename
# os.rename('2022-07-23_LoanMessage_CDAT_UNQ.csv','OS-Demo.txt')

# print(os.stat('OS-Demo.txt'))
# print(os.stat('OS-Demo.txt').st_size)
# print(os.stat('OS-Demo.txt').st_atime)
# # more readable format use datetime
# mod_time = os.stat('OS-Demo.txt').st_mtime
# print(datetime.fromtimestamp(mod_time))

for dirpath, dirnames, filenames in os.walk(r'D:\Users\u124935\OneDrive - Finance of America Holdings, LLC\Desktop'):
    print(f'Current Path: {dirpath}')
    print(f'Directories:  {dirnames}')
    print(f'Files:        {filenames}')

# %% [markdown]
# #### Working with environment variables
# - os.environ prints all variables
# - os.environ.get('HOME')

# %%
import os
from datetime import datetime
print(os.getcwd())

# Novigate to the new location
desktop_path = os.chdir(r'D:\Users\u124935\OneDrive - Finance of America Holdings, LLC\Desktop')
print(os.environ)
print(os.environ.get('HOMEPATH'))
onedrive_path = os.environ.get('ONEDRIVECOMMERCIAL')

# combine all path elements correctly in one path
file_path = os.path.join(onedrive_path,'Desktop','test.txt')
print(file_path)

# Create file for created location
# with open(file_path,'w') as f:
#     f.write

# print the file name
print(os.path.basename('tmp/test.txt'))
# test.txt

# Print the dir name
print(os.path.dirname('tmp/test.txt'))
# tmp

# print both dir and file names
print(os.path.split('tmp/test.txt'))
# ('tmp', 'test.txt')

# check if the file exists
print(os.path.exists('tmp/test.txt'))

# check if its dir
print(os.path.isdir('tmp/test.txt'))

# check if its file

print(os.path.isfile('tmp/test.txt'))

# split extension and the file with dir
print(os.path.splitext('tmp/test.txt'))

print(dir(os.path))
# Out:
# D:\Users\u124935\OneDrive - Finance of America Holdings, LLC\Desktop
# ...
